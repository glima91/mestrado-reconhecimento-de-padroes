# %% [markdown]
# # Apresentação da Disciplina
#
# 1 - Escolha um ambiente para estudar aprendizado de máquina. Pode ser uma das formas apresentadas no vídeo https://youtu.be/wDkyc8Sv4JM, ou outra forma que você souber.
#
# 2 - Faça um jupyter notebook com os códigos apresentados no vídeo https://youtu.be/_dgrpfEuud0.
#
# 3 - Disponibilize seu jupyter notebook no GitHub.

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_boston, load_breast_cancer, load_iris

# %% [markdown]
# ## Exemplo de Regressão

# %%
X, y = load_boston(return_X_y = True)
plt.scatter(X[:,12],y)
plt.show()

# %% [markdown]
# ## Exemplo de Classificação

# %%
X, y = load_breast_cancer(return_X_y=True)
plt.plot(X[:, 20][y==1],X[:, 27][y==1], "gs")
plt.plot(X[:, 20][y==0],X[:, 27][y==0], "ro")
plt.show()

# %% [markdown]
# ## Aprendizado não-supervisionado

# %%
X, y = load_iris(return_X_y = True)
plt.plot(X[:,0][y==0], X[:,1][y==0], "*")
plt.plot(X[:,0][y==1], X[:,1][y==1], "ys")
plt.plot(X[:,0][y==2], X[:,1][y==2], "g^")
plt.show()
